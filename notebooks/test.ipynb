# %%
# charger le dataframe "all_images.csv" dans le dossier data

import os
# -------------------------------------------------------------------
# Project root directory
import pandas as pd

data = pd.read_csv('../data/all_images.csv')

# %%
data.head()
# tracer un histogramme de la colonne "label" du dataframe data en mettant les noms des labels à l'horizontale
data['label'].value_counts().plot(kind='bar')
import matplotlib.pyplot as plt
plt.xticks(rotation=45)
plt.show()

# %%
# Out:
# (35887, 2)
